# %% [markdown]
# # Semana 9 — Apache Spark / PySpark
#
# Resolva cada questão na célula correspondente.
# Leia o enunciado completo em `ex7_spark.md` antes de começar.
#
# > **Regras:**
# > - Nada de `.toPandas()` ou loops Python para transformações
# > - Chame `explain()` em pelo menos uma operação por questão
# > - Sempre feche a SparkSession no final (`spark.stop()`)

# %% [markdown]
# ## Setup — imports comuns

# %%
import os
import sys

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.window import Window
from pyspark.sql.functions import broadcast
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType

print("Python:", sys.executable)
import pyspark; print("PySpark:", pyspark.__version__)
# Out:
# Python: /usr/local/bin/python3.12
# PySpark: 3.5.4

# %% [markdown]
# ---
# ## Q1 — SparkSession, leitura e primeiras transformações

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# 1. Crie a SparkSession com as configs pedidas
spark = SparkSession.builder \
    .appName("Exercicio_Q1") \
    .master("local[*]") \
    .config("spark.ui.enabled", "false") \
    .getOrCreate()

spark.sparkContext.setLogLevel("ERROR")
print("SparkSession criada com sucesso! Versão:", spark.version)

# 2. Crie o DataFrame a partir de lista Python com 10 pedidos
dados_pedidos = [
    (1, 150.0, "entregue"), (2, 80.0, "processando"), (3, 200.0, "entregue"),
    (4, 50.0, "cancelado"), (5, 300.0, "entregue"), (6, 120.0, "entregue"),
    (7, 90.0, "processando"), (8, 400.0, "entregue"), (9, 25.0, "entregue"),
    (10, 600.0, "cancelado")
]
colunas = ["id_pedido", "valor", "status"]
df_pedidos = spark.createDataFrame(dados_pedidos, schema=colunas)

# 3. Aplique filter + withColumn + select (em cadeia)
df_transformado = df_pedidos \
    .filter(col("status") == "entregue") \
    .withColumn("valor_com_taxa", col("valor") * 1.1) \
    .select("id_pedido", "valor_com_taxa")

# 4. Chame explain()
print("--- Plano de Execução ---")
df_transformado.explain()

# 5. Chame show()
print("--- Resultado Final ---")
df_transformado.show()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/10 13:12:58 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# SparkSession criada com sucesso! Versão: 3.5.4
# --- Plano de Execução ---
# == Physical Plan ==
# *(1) Project [id_pedido#0L, (valor#1 * 1.1) AS valor_com_taxa#6]
# +- *(1) Filter (isnotnull(status#2) AND (status#2 = entregue))
#    +- *(1) Scan ExistingRDD[id_pedido#0L,valor#1,status#2]
#
#
# --- Resultado Final ---
# +---------+------------------+
# |id_pedido|    valor_com_taxa|
# +---------+------------------+
# |        1|             165.0|
# |        3|220.00000000000003|
# |        5|             330.0|
# |        6|             132.0|
# |        8|440.00000000000006|
# |        9|27.500000000000004|
# +---------+------------------+

# %% [markdown]
# **Resposta à pergunta de reflexão (escreva aqui):**
#
# _Por que o explain() não executou os dados?_
#
# O explain() não executa os dados porque ele é uma operação voltada ao plano de consulta (query plan), não uma Ação. No Apache Spark, as transformações (como filter, select e withColumn) são Lazy (preguiçosas), o que significa que o Spark apenas constrói um grafo de execução (DAG) sem processar os registros reais.
#
# O método explain() apenas imprime as etapas que o otimizador do Spark (Catalyst) planejou realizar — mostrando os planos Lógico e Físico. O processamento real dos dados só ocorre quando uma Ação é chamada, como o show(), count() ou collect(). Portanto, o explain() serve apenas para inspeção da estratégia de otimização, sem tocar nos dados da lista ou do arquivo.

# %% [markdown]
# ---
# ## Q2 — Narrow vs Wide: identificando shuffle boundaries

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg

spark = SparkSession.builder.appName("Q2_Narrow_vs_Wide").getOrCreate()

# 1. Crie o DataFrame com 50 registros
data = [(i, f"Produto_{i%5}", i * 10.5) for i in range(1, 51)]
df = spark.createDataFrame(data, ["id", "categoria", "preco"])

# 2. Construa o pipeline: filter -> withColumn -> groupBy -> orderBy
df_final = df.filter(col("preco") > 100) \
             .withColumn("preco_com_desconto", col("preco") * 0.9) \
             .groupBy("categoria") \
             .agg(avg("preco_com_desconto").alias("media_preco")) \
             .orderBy("media_preco")

# 3. Chame explain(mode="formatted")
df_final.explain(mode="formatted")

# Para o experimento de remover/mover o orderBy, basta comentar a última linha
# ou movê-la para antes do groupBy para observar a mudança no plano.
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (9)
# +- Sort (8)
#    +- Exchange (7)
#       +- HashAggregate (6)
#          +- Exchange (5)
#             +- HashAggregate (4)
#                +- Project (3)
#                   +- Filter (2)
#                      +- Scan ExistingRDD (1)
#
#
# (1) Scan ExistingRDD
# Output [3]: [id#114L, categoria#115, preco#116]
# Arguments: [id#114L, categoria#115, preco#116], MapPartitionsRDD[31] at applySchemaToPythonRDD at NativeMethodAccessorImpl.java:0, ExistingRDD, UnknownPartitioning(0)
#
# (2) Filter
# Input [3]: [id#114L, categoria#115, preco#116]
# Condition : (isnotnull(preco#116) AND (preco#116 > 100.0))
#
# (3) Project
# Output [2]: [categoria#115, (preco#116 * 0.9) AS preco_com_desconto#120]
# Input [3]: [id#114L, categoria#115, preco#116]
#
# (4) HashAggregate
# Input [2]: [categoria#115, preco_com_desconto#120]
# Keys [1]: [categoria#115]
# Functions [1]: [partial_avg(preco_com_desconto#120)]
# Aggregate Attributes [2]: [sum#133, count#134L]
# Results [3]: [categoria#115, sum#135, count#136L]
#
# (5) Exchange
# Input [3]: [categoria#115, sum#135, count#136L]
# Arguments: hashpartitioning(categoria#115, 200), ENSURE_REQUIREMENTS, [plan_id=149]
#
# (6) HashAggregate
# Input [3]: [categoria#115, sum#135, count#136L]
# Keys [1]: [categoria#115]
# Functions [1]: [avg(preco_com_desconto#120)]
# Aggregate Attributes [1]: [avg(preco_com_desconto#120)#129]
# Results [2]: [categoria#115, avg(preco_com_desconto#120)#129 AS media_preco#130]
#
# (7) Exchange
# Input [2]: [categoria#115, media_preco#130]
# Arguments: rangepartitioning(media_preco#130 ASC NULLS FIRST, 200), ENSURE_REQUIREMENTS, [plan_id=152]
#
# (8) Sort
# Input [2]: [categoria#115, media_preco#130]
# Arguments: [media_preco#130 ASC NULLS FIRST], true, 0
#
# (9) AdaptiveSparkPlan
# Output [2]: [categoria#115, media_preco#130]
# Arguments: isFinalPlan=false

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg

spark = SparkSession.builder.appName("Q2_Narrow_vs_Wide").getOrCreate()

# 1. Crie o DataFrame com 50 registros
data = [(i, f"Produto_{i%5}", i * 10.5) for i in range(1, 51)]
df = spark.createDataFrame(data, ["id", "categoria", "preco"])

# 2. Construa o pipeline: filter -> withColumn -> groupBy -> orderBy
df_final = df.filter(col("preco") > 100) \
             .withColumn("preco_com_desconto", col("preco") * 0.9) \
             .groupBy("categoria") \
             .agg(avg("preco_com_desconto").alias("media_preco")) \
            #  .orderBy("media_preco")

# 3. Chame explain(mode="formatted")
df_final.explain(mode="formatted")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (7)
# +- HashAggregate (6)
#    +- Exchange (5)
#       +- HashAggregate (4)
#          +- Project (3)
#             +- Filter (2)
#                +- Scan ExistingRDD (1)
#
#
# (1) Scan ExistingRDD
# Output [3]: [id#137L, categoria#138, preco#139]
# Arguments: [id#137L, categoria#138, preco#139], MapPartitionsRDD[36] at applySchemaToPythonRDD at NativeMethodAccessorImpl.java:0, ExistingRDD, UnknownPartitioning(0)
#
# (2) Filter
# Input [3]: [id#137L, categoria#138, preco#139]
# Condition : (isnotnull(preco#139) AND (preco#139 > 100.0))
#
# (3) Project
# Output [2]: [categoria#138, (preco#139 * 0.9) AS preco_com_desconto#143]
# Input [3]: [id#137L, categoria#138, preco#139]
#
# (4) HashAggregate
# Input [2]: [categoria#138, preco_com_desconto#143]
# Keys [1]: [categoria#138]
# Functions [1]: [partial_avg(preco_com_desconto#143)]
# Aggregate Attributes [2]: [sum#156, count#157L]
# Results [3]: [categoria#138, sum#158, count#159L]
#
# (5) Exchange
# Input [3]: [categoria#138, sum#158, count#159L]
# Arguments: hashpartitioning(categoria#138, 200), ENSURE_REQUIREMENTS, [plan_id=173]
#
# (6) HashAggregate
# Input [3]: [categoria#138, sum#158, count#159L]
# Keys [1]: [categoria#138]
# Functions [1]: [avg(preco_com_desconto#143)]
# Aggregate Attributes [1]: [avg(preco_com_desconto#143)#152]
# Results [2]: [categoria#138, avg(preco_com_desconto#143)#152 AS media_preco#153]
#
# (7) AdaptiveSparkPlan
# Output [2]: [categoria#138, media_preco#153]
# Arguments: isFinalPlan=false

# %% [markdown]
# **Identificação no plano — baseada no output real:**
#
# **Número de stages:**
# - Com `orderBy`: **3 stages** (2 shuffles = 2 stage boundaries)
# - Sem `orderBy`: **2 stages** (1 shuffle = 1 stage boundary)
#
# **Shuffle boundaries (nós `Exchange`):**
# - Exchange (5): `hashpartitioning(categoria, 200)` — antes do `HashAggregate` final. Garante que todos os registros da mesma categoria cheguem ao mesmo executor para a agregação.
# - Exchange (7): `rangepartitioning(media_preco, 200)` — antes do `Sort`. Necessário para ordenação **global** entre todos os executors (cada executor precisa ver o intervalo de valores que lhe compete).
#
# **Transformações narrow** (dentro da mesma partição, sem mover dados):
# - `Filter` (2), `Project`/`withColumn` (3), `HashAggregate` partial (4)
#
# **Transformações wide** (exigem shuffle):
# - `groupBy + agg` → Exchange (5) com `hashpartitioning`
# - `orderBy` → Exchange (7) com `rangepartitioning`
#
# **Qual shuffle removeria:** o do `orderBy`. Em ETL, ordenação global é raramente necessária — o consumidor downstream (banco, BI tool, Parquet particionado) tem seus próprios mecanismos de ordenação ou não depende da ordem.
#
# **Detalhe crítico — Two-phase aggregation:**
# O Catalyst inseriu `partial_avg` **antes** do shuffle: o nó (4) calcula `sum` e `count` localmente em cada partição e envia apenas esses dois números pelo shuffle. O nó (6) combina com `sum/count` para a média final. Isso pode reduzir em 10–100x o volume de dados transferidos na rede.
#
# **Detalhe de performance — `hashpartitioning(categoria, 200)`:**
# 200 partições para 5 categorias únicas → 195 partições vazias, 195 tasks que rodam e não fazem nada. Usar `spark.conf.set("spark.sql.shuffle.partitions", "4")` ou ativar AQE (`spark.sql.adaptive.enabled=true`) resolve isso automaticamente.

# %% [markdown]
# ---
# ## Q3 — DataFrame API: filter, groupBy, join, window functions

# %%
import random
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.window import Window

spark = SparkSession.builder.appName("Q3").getOrCreate()

# ── df_clientes ────────────────────────────────────────────────────────────────
clientes = [
    (1, "João Silva",     "Premium"),
    (2, "Maria Oliveira", "Standard"),
    (3, "Pedro Costa",    "Premium"),
    (4, "Lucia Alves",    "Standard"),
    (5, "Roberto Nunes",  "Premium"),
]
df_clientes = spark.createDataFrame(clientes, ["id_cliente", "nome", "segmento"])

# ── df_pedidos ─────────────────────────────────────────────────────────────────
# 20 pedidos: clientes 1–5, categorias variadas, valores e meses distribuídos
random.seed(42)
categorias = ["Eletrônicos", "Roupas", "Livros", "Alimentos"]
pedidos = [
    (i, (i % 5) + 1, round(random.uniform(50, 1500), 2),
     categorias[i % 4], (i % 12) + 1)
    for i in range(1, 21)
]
df_pedidos = spark.createDataFrame(
    pedidos, ["id_pedido", "id_cliente", "valor", "categoria", "mes"]
)

print("=== df_clientes ===")
df_clientes.show()
print("=== df_pedidos ===")
df_pedidos.show()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/12 16:55:01 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# === df_clientes ===
# +----------+--------------+--------+
# |id_cliente|          nome|segmento|
# +----------+--------------+--------+
# |         1|    João Silva| Premium|
# |         2|Maria Oliveira|Standard|
# |         3|   Pedro Costa| Premium|
# |         4|   Lucia Alves|Standard|
# |         5| Roberto Nunes| Premium|
# +----------+--------------+--------+
#
# === df_pedidos ===
# +---------+----------+-------+-----------+---+
# |id_pedido|id_cliente|  valor|  categoria|mes|
# +---------+----------+-------+-----------+---+
# |        1|         2| 977.17|     Roupas|  2|
# |        2|         3|  86.27|     Livros|  3|
# |        3|         4| 448.79|  Alimentos|  4|
# |        4|         5| 373.66|Eletrônicos|  5|
# |        5|         1|1117.88|     Roupas|  6|
# |        6|         2|1031.21|     Livros|  7|
# |        7|         3|1343.66|  Alimentos|  8|
# |        8|         4| 176.06|Eletrônicos|  9|
# |        9|         5| 661.79|     Roupas| 10|
# |       10|         1|  93.21|     Livros| 11|
# |       11|         2| 367.03|  Alimentos| 12|
# |       12|         3| 782.77|Eletrônicos|  1|
# |       13|         4|  88.48|     Roupas|  2|
# |       14|         5| 338.31|     Livros|  3|
# |       15|         1| 992.33|  Alimentos|  4|
# |       16|         2| 840.17|Eletrônicos|  5|
# |       17|         3| 369.64|     Roupas|  6|
# |       18|         4| 904.44|     Livros|  7|
# |       19|         5|1223.67|  Alimentos|  8|
# |       20|         1|  59.42|Eletrônicos|  9|
# +---------+----------+-------+-----------+---+
# 26/05/12 16:55:12 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
# Q3.1 — Join + filtro por segmento
# Objetivo: pedidos feitos por clientes Premium, com nome do cliente

df_q31 = (
    df_pedidos
    .join(df_clientes, on="id_cliente", how="inner")   # join pela FK
    .filter(F.col("segmento") == "Premium")            # só clientes Premium
    .select("id_pedido", "nome", "segmento", "categoria", "valor", "mes")
    .orderBy("id_pedido")
)

print("=== Q3.1 — Pedidos de clientes Premium ===")
df_q31.explain(mode="formatted")
df_q31.show(truncate=False)
# Out:
# === Q3.1 — Pedidos de clientes Premium ===
# == Physical Plan ==
# AdaptiveSparkPlan (13)
# +- Sort (12)
#    +- Exchange (11)
#       +- Project (10)
#          +- SortMergeJoin Inner (9)
#             :- Sort (4)
#             :  +- Exchange (3)
#             :     +- Filter (2)
#             :        +- Scan ExistingRDD (1)
#             +- Sort (8)
#                +- Exchange (7)
#                   +- Filter (6)
#                      +- Scan ExistingRDD (5)
#
#
# (1) Scan ExistingRDD
# Output [5]: [id_pedido#6L, id_cliente#7L, valor#8, categoria#9, mes#10L]
# Arguments: [id_pedido#6L, id_cliente#7L, valor#8, categoria#9, mes#10L], MapPartitionsRDD[9] at applySchemaToPythonRDD at NativeMethodAccessorImpl.java:0, ExistingRDD, UnknownPartitioning(0)
#
# (2) Filter
# Input [5]: [id_pedido#6L, id_cliente#7L, valor#8, categoria#9, mes#10L]
# Condition : isnotnull(id_cliente#7L)
#
# (3) Exchange
# Input [5]: [id_pedido#6L, id_cliente#7L, valor#8, categoria#9, mes#10L]
# Arguments: hashpartitioning(id_cliente#7L, 200), ENSURE_REQUIREMENTS, [plan_id=53]
#
# (4) Sort
# Input [5]: [id_pedido#6L, id_cliente#7L, valor#8, categoria#9, mes#10L]
# Arguments: [id_cliente#7L ASC NULLS FIRST], false, 0
#
# (5) Scan ExistingRDD
# Output [3]: [id_cliente#0L, nome#1, segmento#2]
# Arguments: [id_cliente#0L, nome#1, segmento#2], MapPartitionsRDD[4] at applySchemaToPythonRDD at NativeMethodAccessorImpl.java:0, ExistingRDD, UnknownPartitioning(0)
#
# (6) Filter
# Input [3]: [id_cliente#0L, nome#1, segmento#2]
# Condition : ((isnotnull(segmento#2) AND (segmento#2 = Premium)) AND isnotnull(id_cliente#0L))
#
# (7) Exchange
# Input [3]: [id_cliente#0L, nome#1, segmento#2]
# Arguments: hashpartitioning(id_cliente#0L, 200), ENSURE_REQUIREMENTS, [plan_id=54]
#
# (8) Sort
# Input [3]: [id_cliente#0L, nome#1, segmento#2]
# Arguments: [id_cliente#0L ASC NULLS FIRST], false, 0
#
# (9) SortMergeJoin
# Left keys [1]: [id_cliente#7L]
# Right keys [1]: [id_cliente#0L]
# Join type: Inner
# Join condition: None
#
# (10) Project
# Output [6]: [id_pedido#6L, nome#1, segmento#2, categoria#9, valor#8, mes#10L]
# Input [8]: [id_pedido#6L, id_cliente#7L, valor#8, categoria#9, mes#10L, id_cliente#0L, nome#1, segmento#2]
#
# (11) Exchange
# Input [6]: [id_pedido#6L, nome#1, segmento#2, categoria#9, valor#8, mes#10L]
# Arguments: rangepartitioning(id_pedido#6L ASC NULLS FIRST, 200), ENSURE_REQUIREMENTS, [plan_id=60]
#
# (12) Sort
# Input [6]: [id_pedido#6L, nome#1, segmento#2, categoria#9, valor#8, mes#10L]
# Arguments: [id_pedido#6L ASC NULLS FIRST], true, 0
#
# (13) AdaptiveSparkPlan
# Output [6]: [id_pedido#6L, nome#1, segmento#2, categoria#9, valor#8, mes#10L]
# Arguments: isFinalPlan=false
#
#
# +---------+-------------+--------+-----------+-------+---+
# |id_pedido|nome         |segmento|categoria  |valor  |mes|
# +---------+-------------+--------+-----------+-------+---+
# |2        |Pedro Costa  |Premium |Livros     |86.27  |3  |
# |4        |Roberto Nunes|Premium |Eletrônicos|373.66 |5  |
# |5        |João Silva   |Premium |Roupas     |1117.88|6  |
# |7        |Pedro Costa  |Premium |Alimentos  |1343.66|8  |
# |9        |Roberto Nunes|Premium |Roupas     |661.79 |10 |
# |10       |João Silva   |Premium |Livros     |93.21  |11 |
# |12       |Pedro Costa  |Premium |Eletrônicos|782.77 |1  |
# |14       |Roberto Nunes|Premium |Livros     |338.31 |3  |
# |15       |João Silva   |Premium |Alimentos  |992.33 |4  |
# |17       |Pedro Costa  |Premium |Roupas     |369.64 |6  |
# |19       |Roberto Nunes|Premium |Alimentos  |1223.67|8  |
# |20       |João Silva   |Premium |Eletrônicos|59.42  |9  |
# +---------+-------------+--------+-----------+-------+---+

# %%
# Q3.2 — Ranking por cliente (Window Function)
# Objetivo: ranquear pedidos de cada cliente por valor (maior = rank 1)

# Window particionado por cliente, ordenado por valor desc
janela_cliente = Window.partitionBy("id_cliente").orderBy(F.col("valor").desc())

df_q32 = (
    df_pedidos
    .withColumn("rank_valor", F.rank().over(janela_cliente))
    .join(df_clientes, on="id_cliente", how="inner")
    .select("id_cliente", "nome", "id_pedido", "valor", "rank_valor")
    .orderBy("id_cliente", "rank_valor")
)

print("=== Q3.2 — Ranking de pedidos por cliente ===")
df_q32.explain(mode="formatted")
df_q32.show(truncate=False)

# Diferença entre rank(), dense_rank() e row_number():
# rank()        → pula números em caso de empate (1, 1, 3)
# dense_rank()  → não pula (1, 1, 2)
# row_number()  → único sempre, ordem arbitrária nos empates (1, 2, 3)
# Out:
# === Q3.2 — Ranking de pedidos por cliente ===
# == Physical Plan ==
# AdaptiveSparkPlan (16)
# +- Sort (15)
#    +- Exchange (14)
#       +- Project (13)
#          +- SortMergeJoin Inner (12)
#             :- Window (6)
#             :  +- Sort (5)
#             :     +- Exchange (4)
#             :        +- Project (3)
#             :           +- Filter (2)
#             :              +- Scan ExistingRDD (1)
#             +- Sort (11)
#                +- Exchange (10)
#                   +- Project (9)
#                      +- Filter (8)
#                         +- Scan ExistingRDD (7)
#
#
# (1) Scan ExistingRDD
# Output [5]: [id_pedido#6L, id_cliente#7L, valor#8, categoria#9, mes#10L]
# Arguments: [id_pedido#6L, id_cliente#7L, valor#8, categoria#9, mes#10L], MapPartitionsRDD[9] at applySchemaToPythonRDD at NativeMethodAccessorImpl.java:0, ExistingRDD, UnknownPartitioning(0)
#
# (2) Filter
# Input [5]: [id_pedido#6L, id_cliente#7L, valor#8, categoria#9, mes#10L]
# Condition : isnotnull(id_cliente#7L)
#
# (3) Project
# Output [3]: [id_pedido#6L, id_cliente#7L, valor#8]
# Input [5]: [id_pedido#6L, id_cliente#7L, valor#8, categoria#9, mes#10L]
#
# (4) Exchange
# Input [3]: [id_pedido#6L, id_cliente#7L, valor#8]
# Arguments: hashpartitioning(id_cliente#7L, 200), ENSURE_REQUIREMENTS, [plan_id=217]
#
# (5) Sort
# Input [3]: [id_pedido#6L, id_cliente#7L, valor#8]
# Arguments: [id_cliente#7L ASC NULLS FIRST, valor#8 DESC NULLS LAST], false, 0
#
# (6) Window
# Input [3]: [id_pedido#6L, id_cliente#7L, valor#8]
# Arguments: [rank(valor#8) windowspecdefinition(id_cliente#7L, valor#8 DESC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rank_valor#90], [id_cliente#7L], [valor#8 DESC NULLS LAST]
#
# (7) Scan ExistingRDD
# Output [3]: [id_cliente#0L, nome#1, segmento#2]
# Arguments: [id_cliente#0L, nome#1, segmento#2], MapPartitionsRDD[4] at applySchemaToPythonRDD at NativeMethodAccessorImpl.java:0, ExistingRDD, UnknownPartitioning(0)
#
# (8) Filter
# Input [3]: [id_cliente#0L, nome#1, segmento#2]
# Condition : isnotnull(id_cliente#0L)
#
# (9) Project
# Output [2]: [id_cliente#0L, nome#1]
# Input [3]: [id_cliente#0L, nome#1, segmento#2]
#
# (10) Exchange
# Input [2]: [id_cliente#0L, nome#1]
# Arguments: hashpartitioning(id_cliente#0L, 200), ENSURE_REQUIREMENTS, [plan_id=222]
#
# (11) Sort
# Input [2]: [id_cliente#0L, nome#1]
# Arguments: [id_cliente#0L ASC NULLS FIRST], false, 0
#
# (12) SortMergeJoin
# Left keys [1]: [id_cliente#7L]
# Right keys [1]: [id_cliente#0L]
# Join type: Inner
# Join condition: None
#
# (13) Project
# Output [5]: [id_cliente#7L, nome#1, id_pedido#6L, valor#8, rank_valor#90]
# Input [6]: [id_pedido#6L, id_cliente#7L, valor#8, rank_valor#90, id_cliente#0L, nome#1]
#
# (14) Exchange
# Input [5]: [id_cliente#7L, nome#1, id_pedido#6L, valor#8, rank_valor#90]
# Arguments: rangepartitioning(id_cliente#7L ASC NULLS FIRST, rank_valor#90 ASC NULLS FIRST, 200), ENSURE_REQUIREMENTS, [plan_id=227]
#
# (15) Sort
# Input [5]: [id_cliente#7L, nome#1, id_pedido#6L, valor#8, rank_valor#90]
# Arguments: [id_cliente#7L ASC NULLS FIRST, rank_valor#90 ASC NULLS FIRST], true, 0
#
# (16) AdaptiveSparkPlan
# Output [5]: [id_cliente#7L, nome#1, id_pedido#6L, valor#8, rank_valor#90]
# Arguments: isFinalPlan=false
#
#
# +----------+--------------+---------+-------+----------+
# |id_cliente|nome          |id_pedido|valor  |rank_valor|
# +----------+--------------+---------+-------+----------+
# |1         |João Silva    |5        |1117.88|1         |
# |1         |João Silva    |15       |992.33 |2         |
# |1         |João Silva    |10       |93.21  |3         |
# |1         |João Silva    |20       |59.42  |4         |
# |2         |Maria Oliveira|6        |1031.21|1         |
# |2         |Maria Oliveira|1        |977.17 |2         |
# |2         |Maria Oliveira|16       |840.17 |3         |
# |2         |Maria Oliveira|11       |367.03 |4         |
# |3         |Pedro Costa   |7        |1343.66|1         |
# |3         |Pedro Costa   |12       |782.77 |2         |
# |3         |Pedro Costa   |17       |369.64 |3         |
# |3         |Pedro Costa   |2        |86.27  |4         |
# |4         |Lucia Alves   |18       |904.44 |1         |
# |4         |Lucia Alves   |3        |448.79 |2         |
# |4         |Lucia Alves   |8        |176.06 |3         |
# |4         |Lucia Alves   |13       |88.48  |4         |
# |5         |Roberto Nunes |19       |1223.67|1         |
# |5         |Roberto Nunes |9        |661.79 |2         |
# |5         |Roberto Nunes |4        |373.66 |3         |
# |5         |Roberto Nunes |14       |338.31 |4         |
# +----------+--------------+---------+-------+----------+

# %%
# Q3.3 — Crescimento mês a mês com lag()
# Objetivo: faturamento total por mês e variação percentual em relação ao mês anterior

df_mensal = (
    df_pedidos
    .groupBy("mes")
    .agg(F.round(F.sum("valor"), 2).alias("faturamento"))
    .orderBy("mes")
)

# Window ordenada por mês — sem partitionBy porque queremos sequência global
janela_mes = Window.orderBy("mes")

df_q33 = (
    df_mensal
    .withColumn("fat_mes_anterior", F.lag("faturamento", 1).over(janela_mes))
    .withColumn(
        "crescimento_pct",
        F.round(
            (F.col("faturamento") - F.col("fat_mes_anterior"))
            / F.col("fat_mes_anterior") * 100,
            2
        )
    )
)

print("=== Q3.3 — Crescimento mês a mês ===")
df_q33.explain(mode="formatted")
df_q33.show(truncate=False)

# lag(col, offset, default)
# offset=1 → valor da linha anterior na janela
# Primeira linha retorna null (sem mês anterior) — normal e esperado
# Out:
# === Q3.3 — Crescimento mês a mês ===
# == Physical Plan ==
# AdaptiveSparkPlan (12)
# +- Project (11)
#    +- Window (10)
#       +- Sort (9)
#          +- Exchange (8)
#             +- Sort (7)
#                +- Exchange (6)
#                   +- HashAggregate (5)
#                      +- Exchange (4)
#                         +- HashAggregate (3)
#                            +- Project (2)
#                               +- Scan ExistingRDD (1)
#
#
# (1) Scan ExistingRDD
# Output [5]: [id_pedido#6L, id_cliente#7L, valor#8, categoria#9, mes#10L]
# Arguments: [id_pedido#6L, id_cliente#7L, valor#8, categoria#9, mes#10L], MapPartitionsRDD[9] at applySchemaToPythonRDD at NativeMethodAccessorImpl.java:0, ExistingRDD, UnknownPartitioning(0)
#
# (2) Project
# Output [2]: [valor#8, mes#10L]
# Input [5]: [id_pedido#6L, id_cliente#7L, valor#8, categoria#9, mes#10L]
#
# (3) HashAggregate
# Input [2]: [valor#8, mes#10L]
# Keys [1]: [mes#10L]
# Functions [1]: [partial_sum(valor#8)]
# Aggregate Attributes [1]: [sum#167]
# Results [2]: [mes#10L, sum#168]
#
# (4) Exchange
# Input [2]: [mes#10L, sum#168]
# Arguments: hashpartitioning(mes#10L, 200), ENSURE_REQUIREMENTS, [plan_id=420]
#
# (5) HashAggregate
# Input [2]: [mes#10L, sum#168]
# Keys [1]: [mes#10L]
# Functions [1]: [sum(valor#8)]
# Aggregate Attributes [1]: [sum(valor#8)#154]
# Results [2]: [mes#10L, round(sum(valor#8)#154, 2) AS faturamento#155]
#
# (6) Exchange
# Input [2]: [mes#10L, faturamento#155]
# Arguments: rangepartitioning(mes#10L ASC NULLS FIRST, 200), ENSURE_REQUIREMENTS, [plan_id=423]
#
# (7) Sort
# Input [2]: [mes#10L, faturamento#155]
# Arguments: [mes#10L ASC NULLS FIRST], true, 0
#
# (8) Exchange
# Input [2]: [mes#10L, faturamento#155]
# Arguments: SinglePartition, ENSURE_REQUIREMENTS, [plan_id=426]
#
# (9) Sort
# Input [2]: [mes#10L, faturamento#155]
# Arguments: [mes#10L ASC NULLS FIRST], false, 0
#
# (10) Window
# Input [2]: [mes#10L, faturamento#155]
# Arguments: [lag(faturamento#155, -1, null) windowspecdefinition(mes#10L ASC NULLS FIRST, specifiedwindowframe(RowFrame, -1, -1)) AS fat_mes_anterior#158], [mes#10L ASC NULLS FIRST]
#
# (11) Project
# Output [4]: [mes#10L, faturamento#155, fat_mes_anterior#158, round((((faturamento#155 - fat_mes_anterior#158) / fat_mes_anterior#158) * 100.0), 2) AS crescimento_pct#162]
# Input [3]: [mes#10L, faturamento#155, fat_mes_anterior#158]
#
# (12) AdaptiveSparkPlan
# Output [4]: [mes#10L, faturamento#155, fat_mes_anterior#158, crescimento_pct#162]
# Arguments: isFinalPlan=false
# 26/05/12 16:56:17 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/12 16:56:17 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/12 16:56:17 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/12 16:56:17 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/12 16:56:17 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/12 16:56:17 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/12 16:56:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/12 16:56:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/12 16:56:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/12 16:56:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/12 16:56:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/12 16:56:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +---+-----------+----------------+---------------+
# |mes|faturamento|fat_mes_anterior|crescimento_pct|
# +---+-----------+----------------+---------------+
# |1  |782.77     |NULL            |NULL           |
# |2  |1065.65    |782.77          |36.14          |
# |3  |424.58     |1065.65         |-60.16         |
# |4  |1441.12    |424.58          |239.42         |
# |5  |1213.83    |1441.12         |-15.77         |
# |6  |1487.52    |1213.83         |22.55          |
# |7  |1935.65    |1487.52         |30.13          |
# |8  |2567.33    |1935.65         |32.63          |
# |9  |235.48     |2567.33         |-90.83         |
# |10 |661.79     |235.48          |181.04         |
# |11 |93.21      |661.79          |-85.92         |
# |12 |367.03     |93.21           |293.77         |
# +---+-----------+----------------+---------------+

# %%
# Q3.4 — Top categoria por valor médio
# Objetivo: categoria com maior ticket médio, usando uma única expressão encadeada

df_q34 = (
    df_pedidos
    .groupBy("categoria")
    .agg(F.round(F.avg("valor"), 2).alias("ticket_medio"))
    .orderBy(F.col("ticket_medio").desc())
    .limit(1)   # top 1 — equivalent a LIMIT 1 no SQL
)

print("=== Q3.4 — Top categoria por ticket médio ===")
df_q34.explain(mode="formatted")
df_q34.show(truncate=False)

# Alternativa com Window (sem limit) — ranqueia todas as categorias:
janela_rank = Window.orderBy(F.col("ticket_medio").desc())
df_todas_categorias = (
    df_pedidos
    .groupBy("categoria")
    .agg(F.round(F.avg("valor"), 2).alias("ticket_medio"))
    .withColumn("rank", F.dense_rank().over(janela_rank))
)
print("=== Ranking completo de categorias ===")
df_todas_categorias.show(truncate=False)
# Out:
# === Q3.4 — Top categoria por ticket médio ===
# == Physical Plan ==
# AdaptiveSparkPlan (7)
# +- TakeOrderedAndProject (6)
#    +- HashAggregate (5)
#       +- Exchange (4)
#          +- HashAggregate (3)
#             +- Project (2)
#                +- Scan ExistingRDD (1)
#
#
# (1) Scan ExistingRDD
# Output [5]: [id_pedido#6L, id_cliente#7L, valor#8, categoria#9, mes#10L]
# Arguments: [id_pedido#6L, id_cliente#7L, valor#8, categoria#9, mes#10L], MapPartitionsRDD[9] at applySchemaToPythonRDD at NativeMethodAccessorImpl.java:0, ExistingRDD, UnknownPartitioning(0)
#
# (2) Project
# Output [2]: [valor#8, categoria#9]
# Input [5]: [id_pedido#6L, id_cliente#7L, valor#8, categoria#9, mes#10L]
#
# (3) HashAggregate
# Input [2]: [valor#8, categoria#9]
# Keys [1]: [categoria#9]
# Functions [1]: [partial_avg(valor#8)]
# Aggregate Attributes [2]: [sum#198, count#199L]
# Results [3]: [categoria#9, sum#200, count#201L]
#
# (4) Exchange
# Input [3]: [categoria#9, sum#200, count#201L]
# Arguments: hashpartitioning(categoria#9, 200), ENSURE_REQUIREMENTS, [plan_id=612]
#
# (5) HashAggregate
# Input [3]: [categoria#9, sum#200, count#201L]
# Keys [1]: [categoria#9]
# Functions [1]: [avg(valor#8)]
# Aggregate Attributes [1]: [avg(valor#8)#194]
# Results [2]: [categoria#9, round(avg(valor#8)#194, 2) AS ticket_medio#195]
#
# (6) TakeOrderedAndProject
# Input [2]: [categoria#9, ticket_medio#195]
# Arguments: 1, [ticket_medio#195 DESC NULLS LAST], [categoria#9, ticket_medio#195]
#
# (7) AdaptiveSparkPlan
# Output [2]: [categoria#9, ticket_medio#195]
# Arguments: isFinalPlan=false
#
#
# +---------+------------+
# |categoria|ticket_medio|
# +---------+------------+
# |Alimentos|875.1       |
# +---------+------------+
#
# === Ranking completo de categorias ===
# 26/05/12 16:56:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/12 16:56:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/12 16:56:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +-----------+------------+----+
# |categoria  |ticket_medio|rank|
# +-----------+------------+----+
# |Alimentos  |875.1       |1   |
# |Roupas     |642.99      |2   |
# |Livros     |490.69      |3   |
# |Eletrônicos|446.42      |4   |
# +-----------+------------+----+
# 26/05/12 16:56:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/12 16:56:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/05/12 16:56:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.

# %% [markdown]
# ---
# ## Q4 — Performance: broadcast join, shuffle.partitions, AQE

# %%
# Q4.1 — Crie df_grande (1000 registros) e df_categorias (10 registros)

import random
random.seed(7)

# df_grande: tabela de fatos — simula transações
dados_grandes = [
    (i, f"prod_{i}", round(random.uniform(10, 5000), 2), f"cat_{(i % 10) + 1}")
    for i in range(1, 1001)
]
df_grande = spark.createDataFrame(
    dados_grandes, ["id_transacao", "produto", "valor", "id_categoria"]
)

# df_categorias: tabela de dimensão — pequena, candidata a broadcast
dados_cat = [
    (f"cat_{i}", f"Categoria {i}", ["A", "B", "C"][i % 3])
    for i in range(1, 11)
]
df_categorias = spark.createDataFrame(
    dados_cat, ["id_categoria", "nome_categoria", "grupo"]
)

print(f"df_grande: {df_grande.count()} linhas")
df_grande.show(5)
print(f"df_categorias: {df_categorias.count()} linhas")
df_categorias.show()
# Out:
# df_grande: 1000 linhas
# +------------+-------+-------+------------+
# |id_transacao|produto|  valor|id_categoria|
# +------------+-------+-------+------------+
# |           1| prod_1|1625.93|       cat_2|
# |           2| prod_2| 762.74|       cat_3|
# |           3| prod_3|3258.16|       cat_4|
# |           4| prod_4| 371.46|       cat_5|
# |           5| prod_5|2684.05|       cat_6|
# +------------+-------+-------+------------+
# only showing top 5 rows
#
# df_categorias: 10 linhas
# +------------+--------------+-----+
# |id_categoria|nome_categoria|grupo|
# +------------+--------------+-----+
# |       cat_1|   Categoria 1|    B|
# |       cat_2|   Categoria 2|    C|
# |       cat_3|   Categoria 3|    A|
# |       cat_4|   Categoria 4|    B|
# |       cat_5|   Categoria 5|    C|
# |       cat_6|   Categoria 6|    A|
# |       cat_7|   Categoria 7|    B|
# |       cat_8|   Categoria 8|    C|
# |       cat_9|   Categoria 9|    A|
# |      cat_10|  Categoria 10|    B|
# +------------+--------------+-----+

# %%
# Q4.2 — Cenário A: join padrão (broadcast desativado)
# Desativamos o broadcast automático do Spark para forçar SortMergeJoin ou ShuffledHashJoin

spark.conf.set("spark.sql.autoBroadcastJoinThreshold", "-1")  # -1 = desativa

df_join_a = df_grande.join(df_categorias, on="id_categoria", how="inner")

print("=== Cenário A — Join SEM broadcast ===")
df_join_a.explain(mode="formatted")
# Procure por: SortMergeJoin ou ShuffledHashJoin → ambas os lados fazem Exchange (shuffle)
# Out:
# === Cenário A — Join SEM broadcast ===
# == Physical Plan ==
# AdaptiveSparkPlan (11)
# +- Project (10)
#    +- SortMergeJoin Inner (9)
#       :- Sort (4)
#       :  +- Exchange (3)
#       :     +- Filter (2)
#       :        +- Scan ExistingRDD (1)
#       +- Sort (8)
#          +- Exchange (7)
#             +- Filter (6)
#                +- Scan ExistingRDD (5)
#
#
# (1) Scan ExistingRDD
# Output [4]: [id_transacao#253L, produto#254, valor#255, id_categoria#256]
# Arguments: [id_transacao#253L, produto#254, valor#255, id_categoria#256], MapPartitionsRDD[72] at applySchemaToPythonRDD at NativeMethodAccessorImpl.java:0, ExistingRDD, UnknownPartitioning(0)
#
# (2) Filter
# Input [4]: [id_transacao#253L, produto#254, valor#255, id_categoria#256]
# Condition : isnotnull(id_categoria#256)
#
# (3) Exchange
# Input [4]: [id_transacao#253L, produto#254, valor#255, id_categoria#256]
# Arguments: hashpartitioning(id_categoria#256, 200), ENSURE_REQUIREMENTS, [plan_id=853]
#
# (4) Sort
# Input [4]: [id_transacao#253L, produto#254, valor#255, id_categoria#256]
# Arguments: [id_categoria#256 ASC NULLS FIRST], false, 0
#
# (5) Scan ExistingRDD
# Output [3]: [id_categoria#261, nome_categoria#262, grupo#263]
# Arguments: [id_categoria#261, nome_categoria#262, grupo#263], MapPartitionsRDD[77] at applySchemaToPythonRDD at NativeMethodAccessorImpl.java:0, ExistingRDD, UnknownPartitioning(0)
#
# (6) Filter
# Input [3]: [id_categoria#261, nome_categoria#262, grupo#263]
# Condition : isnotnull(id_categoria#261)
#
# (7) Exchange
# Input [3]: [id_categoria#261, nome_categoria#262, grupo#263]
# Arguments: hashpartitioning(id_categoria#261, 200), ENSURE_REQUIREMENTS, [plan_id=854]
#
# (8) Sort
# Input [3]: [id_categoria#261, nome_categoria#262, grupo#263]
# Arguments: [id_categoria#261 ASC NULLS FIRST], false, 0
#
# (9) SortMergeJoin
# Left keys [1]: [id_categoria#256]
# Right keys [1]: [id_categoria#261]
# Join type: Inner
# Join condition: None
#
# (10) Project
# Output [6]: [id_categoria#256, id_transacao#253L, produto#254, valor#255, nome_categoria#262, grupo#263]
# Input [7]: [id_transacao#253L, produto#254, valor#255, id_categoria#256, id_categoria#261, nome_categoria#262, grupo#263]
#
# (11) AdaptiveSparkPlan
# Output [6]: [id_categoria#256, id_transacao#253L, produto#254, valor#255, nome_categoria#262, grupo#263]
# Arguments: isFinalPlan=false

# %%
# Q4.3 — Cenário B: broadcast join explícito
# broadcast() envolve o df pequeno — o Spark copia df_categorias para CADA executor
# sem nenhum shuffle em nenhum dos lados

from pyspark.sql.functions import broadcast

df_join_b = df_grande.join(broadcast(df_categorias), on="id_categoria", how="inner")

print("=== Cenário B — Join COM broadcast ===")
df_join_b.explain(mode="formatted")
# Procure por: BroadcastHashJoin → apenas o lado grande é lido localmente
# Não há Exchange (shuffle) para df_categorias
# Out:
# === Cenário B — Join COM broadcast ===
# == Physical Plan ==
# AdaptiveSparkPlan (8)
# +- Project (7)
#    +- BroadcastHashJoin Inner BuildRight (6)
#       :- Filter (2)
#       :  +- Scan ExistingRDD (1)
#       +- BroadcastExchange (5)
#          +- Filter (4)
#             +- Scan ExistingRDD (3)
#
#
# (1) Scan ExistingRDD
# Output [4]: [id_transacao#253L, produto#254, valor#255, id_categoria#256]
# Arguments: [id_transacao#253L, produto#254, valor#255, id_categoria#256], MapPartitionsRDD[72] at applySchemaToPythonRDD at NativeMethodAccessorImpl.java:0, ExistingRDD, UnknownPartitioning(0)
#
# (2) Filter
# Input [4]: [id_transacao#253L, produto#254, valor#255, id_categoria#256]
# Condition : isnotnull(id_categoria#256)
#
# (3) Scan ExistingRDD
# Output [3]: [id_categoria#261, nome_categoria#262, grupo#263]
# Arguments: [id_categoria#261, nome_categoria#262, grupo#263], MapPartitionsRDD[77] at applySchemaToPythonRDD at NativeMethodAccessorImpl.java:0, ExistingRDD, UnknownPartitioning(0)
#
# (4) Filter
# Input [3]: [id_categoria#261, nome_categoria#262, grupo#263]
# Condition : isnotnull(id_categoria#261)
#
# (5) BroadcastExchange
# Input [3]: [id_categoria#261, nome_categoria#262, grupo#263]
# Arguments: HashedRelationBroadcastMode(List(input[0, string, false]),false), [plan_id=883]
#
# (6) BroadcastHashJoin
# Left keys [1]: [id_categoria#256]
# Right keys [1]: [id_categoria#261]
# Join type: Inner
# Join condition: None
#
# (7) Project
# Output [6]: [id_categoria#256, id_transacao#253L, produto#254, valor#255, nome_categoria#262, grupo#263]
# Input [7]: [id_transacao#253L, produto#254, valor#255, id_categoria#256, id_categoria#261, nome_categoria#262, grupo#263]
#
# (8) AdaptiveSparkPlan
# Output [6]: [id_categoria#256, id_transacao#253L, produto#254, valor#255, nome_categoria#262, grupo#263]
# Arguments: isFinalPlan=false

# %%
# Q4.4 — Experimento com shuffle.partitions: 200 vs 4

# ── Cenário 200 (padrão do Spark) ─────────────────────────────────────────────
spark.conf.set("spark.sql.shuffle.partitions", "200")
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", "-1")  # broadcast desativado

df_agg_200 = (
    df_grande
    .groupBy("id_categoria")
    .agg(F.sum("valor").alias("total"))
)
print("=== shuffle.partitions = 200 ===")
df_agg_200.explain(mode="formatted")
# O Exchange mostrará: hashpartitioning(id_categoria, 200)
# 200 tarefas no Spark UI — a maioria processando 0 registros (10 categorias únicas)

# ── Cenário 4 (ajustado ao volume real) ───────────────────────────────────────
spark.conf.set("spark.sql.shuffle.partitions", "4")

df_agg_4 = (
    df_grande
    .groupBy("id_categoria")
    .agg(F.sum("valor").alias("total"))
)
print("=== shuffle.partitions = 4 ===")
df_agg_4.explain(mode="formatted")
# O Exchange mostrará: hashpartitioning(id_categoria, 4)
# 4 tarefas no Spark UI — muito mais eficiente para este volume

# Restaura default
spark.conf.set("spark.sql.shuffle.partitions", "200")
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", str(10 * 1024 * 1024))  # 10MB
# Out:
# === shuffle.partitions = 200 ===
# == Physical Plan ==
# AdaptiveSparkPlan (6)
# +- HashAggregate (5)
#    +- Exchange (4)
#       +- HashAggregate (3)
#          +- Project (2)
#             +- Scan ExistingRDD (1)
#
#
# (1) Scan ExistingRDD
# Output [4]: [id_transacao#253L, produto#254, valor#255, id_categoria#256]
# Arguments: [id_transacao#253L, produto#254, valor#255, id_categoria#256], MapPartitionsRDD[72] at applySchemaToPythonRDD at NativeMethodAccessorImpl.java:0, ExistingRDD, UnknownPartitioning(0)
#
# (2) Project
# Output [2]: [valor#255, id_categoria#256]
# Input [4]: [id_transacao#253L, produto#254, valor#255, id_categoria#256]
#
# (3) HashAggregate
# Input [2]: [valor#255, id_categoria#256]
# Keys [1]: [id_categoria#256]
# Functions [1]: [partial_sum(valor#255)]
# Aggregate Attributes [1]: [sum#334]
# Results [2]: [id_categoria#256, sum#335]
#
# (4) Exchange
# Input [2]: [id_categoria#256, sum#335]
# Arguments: hashpartitioning(id_categoria#256, 200), ENSURE_REQUIREMENTS, [plan_id=901]
#
# (5) HashAggregate
# Input [2]: [id_categoria#256, sum#335]
# Keys [1]: [id_categoria#256]
# Functions [1]: [sum(valor#255)]
# Aggregate Attributes [1]: [sum(valor#255)#330]
# Results [2]: [id_categoria#256, sum(valor#255)#330 AS total#331]
#
# (6) AdaptiveSparkPlan
# Output [2]: [id_categoria#256, total#331]
# Arguments: isFinalPlan=false
#
#
# === shuffle.partitions = 4 ===
# == Physical Plan ==
# AdaptiveSparkPlan (6)
# +- HashAggregate (5)
#    +- Exchange (4)
#       +- HashAggregate (3)
#          +- Project (2)
#             +- Scan ExistingRDD (1)
#
#
# (1) Scan ExistingRDD
# Output [4]: [id_transacao#253L, produto#254, valor#255, id_categoria#256]
# Arguments: [id_transacao#253L, produto#254, valor#255, id_categoria#256], MapPartitionsRDD[72] at applySchemaToPythonRDD at NativeMethodAccessorImpl.java:0, ExistingRDD, UnknownPartitioning(0)
#
# (2) Project
# Output [2]: [valor#255, id_categoria#256]
# Input [4]: [id_transacao#253L, produto#254, valor#255, id_categoria#256]
#
# (3) HashAggregate
# Input [2]: [valor#255, id_categoria#256]
# Keys [1]: [id_categoria#256]
# Functions [1]: [partial_sum(valor#255)]
# Aggregate Attributes [1]: [sum#344]
# Results [2]: [id_categoria#256, sum#345]
#
# (4) Exchange
# Input [2]: [id_categoria#256, sum#345]
# Arguments: hashpartitioning(id_categoria#256, 4), ENSURE_REQUIREMENTS, [plan_id=918]
#
# (5) HashAggregate
# Input [2]: [id_categoria#256, sum#345]
# Keys [1]: [id_categoria#256]
# Functions [1]: [sum(valor#255)]
# Aggregate Attributes [1]: [sum(valor#255)#340]
# Results [2]: [id_categoria#256, sum(valor#255)#340 AS total#341]
#
# (6) AdaptiveSparkPlan
# Output [2]: [id_categoria#256, total#341]
# Arguments: isFinalPlan=false

# %% [markdown]
# **Resposta (escreva aqui):**
#
# - **Estratégia no Cenário A:** `SortMergeJoin` (ou `ShuffledHashJoin`). Com broadcast desativado, o Spark embaralha (shuffle) **os dois lados** da junção para que registros com a mesma chave cheguem ao mesmo executor. Custo: dois `Exchange` no plano — um para cada DataFrame.
#
# - **Estratégia no Cenário B:** `BroadcastHashJoin`. O Spark serializa `df_categorias` inteiro e envia uma cópia para **cada executor**. Cada executor faz o join localmente contra sua partição de `df_grande`, sem nenhum shuffle. Custo: zero `Exchange` no plano.
#
# - **Por que broadcast é mais rápido:** No SortMergeJoin, ambos os DataFrames precisam ser redistribuídos pela rede (shuffle) — isso envolve serialização, transferência de bytes entre nós, deserialização e sort. No BroadcastHashJoin, apenas o DataFrame pequeno trafega pela rede (uma vez, para cada executor), e o join é resolvido via hash lookup em memória. Para tabelas de dimensão pequenas (< 10 MB, tipicamente), o custo de broadcast é marginal comparado ao shuffle evitado.
#
# - **Risco de broadcast em tabela grande:** Se você fizer `broadcast(df_grande)` com 1 GB de dados, o driver precisará coletar esse DataFrame, serializar e enviar 1 GB para **cada executor**. Isso pode saturar a rede, estourar a memória dos executores (e do driver) e causar OOM (`OutOfMemoryError`). A regra prática é usar broadcast apenas para tabelas que cabem confortavelmente na memória de um executor — o default do Spark é 10 MB (`spark.sql.autoBroadcastJoinThreshold`).
#
# - **Efeito de shuffle.partitions=200 para dados pequenos:** Com 1000 registros e 10 categorias únicas, o Spark cria 200 partições após o shuffle — mas apenas 10 contêm dados. As outras 190 são partições vazias que o scheduler ainda precisa agendar, inicializar e finalizar como tasks. O Spark UI mostrará 200 tasks, a maioria com 0 registros e duração de milissegundos — overhead puro. Reduzir para 4 (número próximo ao de categorias únicas) concentra o trabalho, elimina o overhead e reduz o tempo total. Em produção, use `spark.sql.adaptive.enabled=true` para que o AQE (Adaptive Query Execution) ajuste automaticamente o número de partições pós-shuffle com base no volume real dos dados.

# %% [markdown]
# ---
# ## Q5 — Leitura e escrita de Parquet particionado

# %%
# Q5.1 — Crie DataFrame com 200 transações (ano 2022-2024, meses 1-12)

import random
random.seed(99)

anos = [2022, 2023, 2024]
meses = list(range(1, 13))
categorias = ["Eletrônicos", "Roupas", "Livros", "Alimentos", "Esportes"]

transacoes = [
    (
        i,
        random.choice(anos),
        random.choice(meses),
        random.choice(categorias),
        round(random.uniform(20, 3000), 2)
    )
    for i in range(1, 201)
]

df_transacoes = spark.createDataFrame(
    transacoes, ["id_transacao", "ano", "mes", "categoria", "valor"]
)

print(f"Total de transações: {df_transacoes.count()}")
df_transacoes.show(10)
df_transacoes.printSchema()
# Out:
# Total de transações: 200
# +------------+----+---+-----------+-------+
# |id_transacao| ano|mes|  categoria|  valor|
# +------------+----+---+-----------+-------+
# |           1|2023|  7|     Roupas|1806.33|
# |           2|2022|  4|     Roupas|2284.43|
# |           3|2023| 12|  Alimentos|1601.82|
# |           4|2024|  9|Eletrônicos|2816.36|
# |           5|2023|  4|  Alimentos|2172.23|
# |           6|2024|  4|     Livros|2470.53|
# |           7|2024|  4|     Roupas|1395.22|
# |           8|2022| 10|     Livros| 267.24|
# |           9|2024|  9|Eletrônicos|1417.74|
# |          10|2023|  1|     Livros| 1682.7|
# +------------+----+---+-----------+-------+
# only showing top 10 rows
#
# root
#  |-- id_transacao: long (nullable = true)
#  |-- ano: long (nullable = true)
#  |-- mes: long (nullable = true)
#  |-- categoria: string (nullable = true)
#  |-- valor: double (nullable = true)

# %%
# Q5.2 — Escreva particionado por ano e mes

output_path = "output/transacoes"

(
    df_transacoes
    .write
    .mode("overwrite")
    .partitionBy("ano", "mes")          # cria hierarquia de diretórios ano=X/mes=Y/
    .parquet(output_path)
)

print(f"Escrito em: {output_path}")

# Explora a estrutura de diretórios gerada
import os

print("\n=== Estrutura de diretórios ===")
for raiz, dirs, arquivos in os.walk(output_path):
    nivel = raiz.replace(output_path, "").count(os.sep)
    indent = "  " * nivel
    print(f"{indent}{os.path.basename(raiz)}/")
    if nivel == 2:   # só mostra arquivos nas partições folha (ano=X/mes=Y/)
        for arq in arquivos[:1]:
            print(f"{indent}  {arq}")
        if len(arquivos) > 1:
            print(f"{indent}  ... ({len(arquivos)} arquivo(s))")
# Out:
# 26/05/12 16:58:50 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# Escrito em: output/transacoes
#
# === Estrutura de diretórios ===
# transacoes/
#   ano=2022/
#     mes=1/
#       .part-00004-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (6 arquivo(s))
#     mes=10/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (12 arquivo(s))
#     mes=11/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (8 arquivo(s))
#     mes=12/
#       .part-00002-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (12 arquivo(s))
#     mes=2/
#       .part-00002-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (10 arquivo(s))
#     mes=3/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (10 arquivo(s))
#     mes=4/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (6 arquivo(s))
#     mes=5/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (12 arquivo(s))
#     mes=6/
#       .part-00003-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (6 arquivo(s))
#     mes=7/
#       .part-00002-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (8 arquivo(s))
#     mes=8/
#       .part-00002-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (6 arquivo(s))
#     mes=9/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (12 arquivo(s))
#   ano=2023/
#     mes=1/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (8 arquivo(s))
#     mes=10/
#       .part-00002-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (6 arquivo(s))
#     mes=11/
#       .part-00001-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (8 arquivo(s))
#     mes=12/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (8 arquivo(s))
#     mes=2/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (10 arquivo(s))
#     mes=3/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (8 arquivo(s))
#     mes=4/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (10 arquivo(s))
#     mes=5/
#       .part-00006-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (4 arquivo(s))
#     mes=6/
#       .part-00003-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (2 arquivo(s))
#     mes=7/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (8 arquivo(s))
#     mes=8/
#       .part-00002-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (4 arquivo(s))
#     mes=9/
#       .part-00005-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (2 arquivo(s))
#   ano=2024/
#     mes=1/
#       .part-00002-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (4 arquivo(s))
#     mes=10/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (10 arquivo(s))
#     mes=11/
#       .part-00001-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (12 arquivo(s))
#     mes=2/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (14 arquivo(s))
#     mes=3/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (8 arquivo(s))
#     mes=4/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (10 arquivo(s))
#     mes=5/
#       .part-00004-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (8 arquivo(s))
#     mes=6/
#       .part-00001-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (8 arquivo(s))
#     mes=7/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (10 arquivo(s))
#     mes=8/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (4 arquivo(s))
#     mes=9/
#       .part-00000-f68250cc-a23f-4fd6-8d37-5ff384ddc15b.c000.snappy.parquet.crc
#       ... (8 arquivo(s))

# %%
# Q5.3 — Leia com filtro e chame explain() — procure por PartitionFilters

df_leitura = spark.read.parquet("output/transacoes")

# Filtra só 2023 — o Spark deve usar Partition Pruning: ler apenas ano=2023/
df_filtrado = df_leitura.filter(F.col("ano") == 2023)

print("=== explain() com filtro de partição ===")
df_filtrado.explain(mode="formatted")

# O que procurar no plano:
# PartitionFilters: [isnotnull(ano#X), (ano#X = 2023)]
#   → Spark NÃO leu as partições ano=2022 e ano=2024
# PushedFilters vs PartitionFilters:
#   - PartitionFilters → eliminação de diretórios inteiros (Partition Pruning)
#   - PushedFilters    → filtro dentro do arquivo Parquet (Predicate Pushdown)

print(f"\nRegistros em 2023: {df_filtrado.count()}")

# Compare: filtrar por coluna NÃO-particionada (categoria) não faz Partition Pruning
df_sem_pruning = df_leitura.filter(F.col("categoria") == "Livros")
print("\n=== explain() SEM PartitionFilters (filtro por categoria) ===")
df_sem_pruning.explain(mode="formatted")
# Repare: nenhum PartitionFilters — o Spark lê TODOS os diretórios
# Out:
# === explain() com filtro de partição ===
# == Physical Plan ==
# * ColumnarToRow (2)
# +- Scan parquet  (1)
#
#
# (1) Scan parquet
# Output [5]: [id_transacao#431L, categoria#432, valor#433, ano#434, mes#435]
# Batched: true
# Location: InMemoryFileIndex [file:/workspace/output/transacoes]
# PartitionFilters: [isnotnull(ano#434), (ano#434 = 2023)]
# ReadSchema: struct<id_transacao:bigint,categoria:string,valor:double>
#
# (2) ColumnarToRow [codegen id : 1]
# Input [5]: [id_transacao#431L, categoria#432, valor#433, ano#434, mes#435]
#
#
#
# Registros em 2023: 55
#
# === explain() SEM PartitionFilters (filtro por categoria) ===
# == Physical Plan ==
# * Filter (3)
# +- * ColumnarToRow (2)
#    +- Scan parquet  (1)
#
#
# (1) Scan parquet
# Output [5]: [id_transacao#431L, categoria#432, valor#433, ano#434, mes#435]
# Batched: true
# Location: InMemoryFileIndex [file:/workspace/output/transacoes]
# PushedFilters: [IsNotNull(categoria), EqualTo(categoria,Livros)]
# ReadSchema: struct<id_transacao:bigint,categoria:string,valor:double>
#
# (2) ColumnarToRow [codegen id : 1]
# Input [5]: [id_transacao#431L, categoria#432, valor#433, ano#434, mes#435]
#
# (3) Filter [codegen id : 1]
# Input [5]: [id_transacao#431L, categoria#432, valor#433, ano#434, mes#435]
# Condition : (isnotnull(categoria#432) AND (categoria#432 = Livros))

# %%
# Q5.4 — Leia diretamente uma partição específica

df_jun_2023 = spark.read.parquet("output/transacoes/ano=2023/mes=6/")

print("=== Partição ano=2023/mes=6 ===")
df_jun_2023.show(truncate=False)
print(f"Registros: {df_jun_2023.count()}")

# Atenção: ao ler uma partição diretamente, as colunas de partição (ano, mes)
# NÃO aparecem automaticamente no schema — o Spark as infere do path apenas
# quando você lê o diretório raiz com spark.read.parquet("output/transacoes")
print("\nSchema ao ler partição diretamente (sem ano/mes):")
df_jun_2023.printSchema()

print("\nSchema ao ler raiz (com ano e mes como colunas):")
spark.read.parquet("output/transacoes").filter(
    (F.col("ano") == 2023) & (F.col("mes") == 6)
).printSchema()
# Out:
# === Partição ano=2023/mes=6 ===
# +------------+---------+-------+
# |id_transacao|categoria|valor  |
# +------------+---------+-------+
# |96          |Livros   |2420.36|
# +------------+---------+-------+
#
# Registros: 1
#
# Schema ao ler partição diretamente (sem ano/mes):
# root
#  |-- id_transacao: long (nullable = true)
#  |-- categoria: string (nullable = true)
#  |-- valor: double (nullable = true)
#
#
# Schema ao ler raiz (com ano e mes como colunas):
# root
#  |-- id_transacao: long (nullable = true)
#  |-- categoria: string (nullable = true)
#  |-- valor: double (nullable = true)
#  |-- ano: integer (nullable = true)
#  |-- mes: integer (nullable = true)

# %% [markdown]
# **Resposta (escreva aqui):**
#
# - **Estrutura de diretórios encontrada:**
#   ```
#   output/transacoes/
#     ano=2022/
#       mes=1/   → part-00000-....parquet
#       mes=2/   → part-00000-....parquet
#       ...
#       mes=12/  → part-00000-....parquet
#     ano=2023/
#       mes=1/ ... mes=12/
#     ano=2024/
#       mes=1/ ... mes=12/
#   ```
#   Cada combinação `ano=X/mes=Y/` é uma partição física — um diretório contendo um ou mais arquivos Parquet. O Spark usa o nome do diretório (`ano=2023`) para inferir o valor das colunas de partição sem precisar abrir o arquivo.
#
# - **O explain() mostrou PartitionFilters? O que isso significa:**
#   Sim. `PartitionFilters: [isnotnull(ano#X), (ano#X = 2023)]` significa que o Spark aplicou **Partition Pruning** — em vez de abrir todos os diretórios de todas as partições, ele identificou no metadado do filesystem quais diretórios satisfazem o filtro `ano == 2023` e leu **apenas** `ano=2023/mes=1/` até `ano=2023/mes=12/`. As partições de 2022 e 2024 nunca foram abertas, nem listadas. Isso é a vantagem central do dado particionado: a seletividade acontece no nível de I/O, antes de qualquer processamento.
#
# - **`(ano, mes, categoria)` vs `(ano, mes)` — qual é melhor para leitura de "todos os dados de 2023":**
#   `(ano, mes)` é melhor para essa consulta. Com `(ano, mes, categoria)`, o Spark precisaria de filtros exatos em `ano`, `mes` **e** `categoria` para atingir Partition Pruning eficiente. Um filtro só em `ano=2023` ainda percorreria os 5 subdiretórios de categoria em cada um dos 12 meses (60 diretórios vs 12). Além disso, quanto mais granular a partição, mais arquivos pequenos são criados — o famoso "small files problem", que degrada tanto o Spark (mais tasks) quanto o filesystem (mais metadados). A regra geral: **particione pelas colunas que aparecem nos filtros mais frequentes das queries, do mais geral para o mais específico** — e evite colunas de alta cardinalidade (como `produto_id`) que explodem o número de partições.

# %% [markdown]
# ---
# ## Finalização

# %%
spark.stop()
